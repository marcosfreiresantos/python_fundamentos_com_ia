# %% [markdown]
# <!-- Trabalho Desenvolvido no Curso da Data Science Academy - www.datascienceacademy.com.br -->
# # <font color='blue' size='5'>Data Science Academy</font>
# # <font color='blue' size='5'>Fundamentos de Linguagem Python - Do Básico a Aplicações de IA</font>
# # <font color='blue' size='5'>Lógica de Programação, Variáveis, Tipos e Estruturas de Dados</font>

# %% [markdown]
# ### 1. Lógica de Programação e Pseudocódigo

# %% [markdown]
# ##### O Que é Lógica de Programação?
#
# Antes de escrever código em uma linguagem de programação, é fundamental entender a lógica por trás da solução de um problema. Um algoritmo é uma sequência de passos finitos e bem definidos para resolver um problema. O pseudocódigo é uma forma de representar esses passos de maneira informal e próxima da linguagem humana, antes de traduzi-los para Python.
#
#
# ##### O Que é Pseudocódigo?
#
# **Pseudocódigo** é uma forma de descrever algoritmos usando uma linguagem intermediária entre o português (ou outro idioma natural) e uma linguagem de programação real (como Python, Java, C++).
#
# Ele não segue regras rígidas de sintaxe, mas utiliza estruturas comuns da programação (como se, então, senão, enquanto, para cada, função, etc.), escritas de maneira simples e legível para humanos.
#
# 👉 A ideia é focar na lógica do algoritmo, sem se preocupar com os detalhes técnicos da linguagem que será usada depois.

# %% [markdown]
# <p>
# INÍCIO
#
#     LEIA nota1
#
#     LEIA nota2
#
#     CALCULE media = (nota1 + nota2) / 2
#
#     ESCREVA "A média do aluno é:", media
#
#     SE media >= 7.0 ENTÃO
#
#         ESCREVA "Aluno Aprovado!"
#
#     SENÃO
#
#         ESCREVA "Aluno Reprovado."
# FIM
# </p>

# %%
# Traduzindo o pseudocódigo para Python

nota1 = 7.5
nota2 = 8.0

media = (nota1 + nota2) / 2

if media >= 7.0:
    print('Aluno aprovado')
else:
    print('Aluno reprovado')
# Out:
# Aluno aprovado

# %% [markdown]
# ### 2. Variáveis: Declaração, Atribuição e Regras de Nomenclatura
#
# Uma variável é um espaço na memória do computador destinado a armazenar dados. Em Python, a declaração e a atribuição de um valor a uma variável são feitas simultaneamente. Regras de Nomenclatura:
#
# - Nomes de variáveis devem começar com uma letra ou um underscore (_).
#
# - Não podem começar com um número.
#
# - Podem conter apenas caracteres alfanuméricos e underscores (A-z, 0-9 e _).
#
# - São "case-sensitive" (idade é diferente de Idade).

# %%
# Declaração e atribuição de variáveis
nome_completo = "Bob da Silva"   # String (texto)
idade = 30                       # Integer (inteiro)
altura = 1.76                    # Float (ponto flutuante)
eh_estudante = True              # Boolean (booleano)

# %%
print(f'Nome: {nome_completo}')
print(f'idade: {idade} anos')
print(f'Altura: {altura}m')
print(f'É estudante? {eh_estudante}')
# Out:
# Nome: Bob da Silva
# idade: 30 anos
# Altura: 1.76m
# É estudante? True

# %%
# Exemplo de nomes de variáveis inválidos (descomente para ver o erro)
# 1nome = "Inválido"
# nome-completo = "Inválido"

# %% [markdown]
# Python é uma linguagem dinamicamente "tipada". Você não precisa declarar o tipo das variáveis ao criá-las, pois Python descobre automaticamente pelo valor atribuído:

# %%
x = 10       # tipo int
y1 = 10      # tipo int
y2 = "10"    # tipo str

# %%
type(x)
# Out:
# int

# %%
type(y1)
# Out:
# int

# %%
type(y2)
# Out:
# str

# %%
# Podemos somar tipos numéricos
print(x + y1)
# Out:
# 20

# %%
# Mas não podemos somar número com string
print(x + y2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Mas não podemos somar número com string
# ----> 2 print(x + y2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Ou seja, Python não "mistura" tipos incompatíveis automaticamente e isso mostra que a linguagem não é fracamente tipada.

# %% [markdown]
# ### 3. Escopo de Variáveis
#
# O escopo de uma variável define onde ela pode ser acessada no código.
#
# - Variáveis Globais: Declaradas fora de qualquer função. Podem ser acessadas de qualquer lugar do código.
#
# - Variáveis Locais: Declaradas dentro de uma função. Só podem ser acessadas dentro daquela função.

# %%
# Variável Global
saudacao = "Olá, mundo!"
nome = "Aluno DSA"

# Função
def minha_funcao_dsa():

    # Váriavel Local
    nome = "Ana"
    print(f"\nDentro da função: {nome}")
    print(f"\nAcessando a variável global de dentro da função: {saudacao}")
    
minha_funcao_dsa()

print(f"\nFora da Função: {saudacao}")
print(f"\nFora da Função: {nome}")
# Out:
# Dentro da função: Ana
#
# Acessando a variável global de dentro da função: Olá, mundo!
#
# Fora da Função: Olá, mundo!
#
# Fora da Função: Aluno DSA

# %%
# Função
def minha_funcao_dsa():

    # Variável Local
    nome_local = "Ana"
    print(f"\nDentro da função: {nome}")
    print(f"\nAcessando a variável global de dentro da função: {saudacao}")


minha_funcao_dsa()

# Tentar acessar a variável local fora da função resultará em um erro (descomente para ver)
print(f"Tentando acessar 'nome' fora da função: {nome_local}")
# Out:
# Dentro da função: Aluno DSA
#
# Acessando a variável global de dentro da função: Olá, mundo!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 13
#      10 minha_funcao_dsa()
#      12 # Tentar acessar a variável local fora da função resultará em um erro (descomente para ver)
# ---> 13 print(f"Tentando acessar 'nome' fora da função: {nome_local}")
#
# NameError: name 'nome_local' is not defined

# %% [markdown]
# ### 4. Tipos Primitivos
#
# Estes são os tipos de dados mais básicos em Python

# %%
# Integer (inteiro)
numero_inteiro = 100
print(f"Valor: {numero_inteiro}, Tipo: {type(numero_inteiro)}")
# Out:
# Valor: 100, Tipo: <class 'int'>

# %%
# Float (Ponto Flutuante)
numero_decimal = 19.99
print(f"Valor: {numero_decimal}, Tipo: {type(numero_decimal)}")
# Out:
# Valor: 19.99, Tipo: <class 'float'>

# %%
# String (Texto)
texto = "Python é inacreditavél"
print(f"valor: {texto}, Tipo: {type(texto)}")
# Out:
# valor: Python é inacreditavél, Tipo: <class 'str'>

# %%
# Boolean (Booleano)
verdadeiro = True
falso = False
print(f"valor: {verdadeiro}, Tipo: {type(verdadeiro)}")
print(f"valor: {falso}, Tipo: {type(falso)}")
# Out:
# valor: True, Tipo: <class 'bool'>
# valor: False, Tipo: <class 'bool'>

# %% [markdown]
# ### 5.0 Operadores Aritméticos, de Comparação e Lógicos

# %% [markdown]
# ##### 5.1 Operadores Artméticos

# %%
# Definição de variáveis
a = 10
b = 3

# %%
# Usando operadores aritméticos
soma = a + b              # Adição
subtracao = a - b         # Subtração
multiplicacao = a * b     # Multiplicação
divisao = a / b           # Divisão (resultado é sempre float)
divisao_inteira = a // b  # Divisão inteira (descarta a parte decimal)
modulo = a % b            # Módulo (resto da divisão)
potencia = a ** b         # Potenciação

# %%
print(f'{a} + {b} = {soma}')
print(f'{a} - {b} = {subtracao}')
print(f'{a} * {b} = {multiplicacao}')
print(f'{a} / {b} = {divisao:.2f}')
print(f'{a} // {b} = {divisao_inteira}')
print(f'{a} % {b} = {modulo}')
print(f'{a} ** {b} = {potencia}')
# Out:
# 10 + 3 = 13
# 10 - 3 = 7
# 10 * 3 = 30
# 10 / 3 = 3.33
# 10 // 3 = 3
# 10 % 3 = 1
# 10 ** 3 = 1000

# %%
# As regras da matemática de aplicam aqui normalmente

# Variáveis
a = 10
b = 0

# Tentativa de divisão por zero
a/b
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 8
#       5 b = 0
#       7 # Tentativa de divisão por zero
# ----> 8 a/b
#
# ZeroDivisionError: division by zero

# %%
# Cuidado. Isso não pode!
8 + 's'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Cuidado. Isso não pode!
# ----> 2 8 + 's'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Mas isso pode! (não é soma, é concatenação)
'8' + 's'
# Out:
# '8s'

# %% [markdown]
# #### 5.2. Operadores de Comparação
#
# Usados para comparar valores. O resultado é sempre um Boolean (True ou False).

# %%
# Definição de variáveis
x = 5
y = 10

# %%
# Operador "maior que"
x > y
# Out:
# False

# %%
# Operador "menor que"
x < y
# Out:
# True

# %%
# Operador "igual a"
x == y
# Out:
# False

# %%
# Operador "diferente de"
x != y
# Out:
# True

# %%
# Operador "maior ou igual a"
x >= 5
# Out:
# True

# %%
# Operador "maior ou igual a"
x >= 5
# Out:
# True

# %%
# Operador "menor ou igual a"
x <= y
# Out:
# True

# %%
print(f"{x} > {y} ? {x > y}")      # Maior que
print(f"{x} < {y} ? {x < y}")      # Menor que
print(f"{x} == {y} ? {x == y}")    # Igual a
print(f"{x} != {y} ? {x != y}")    # Diferente de
print(f"{x} >= 5 ? {x >= 5}")      # Maior ou igual a
print(f"{x} <= {y} ? {x <= y}")    # Menor ou igual a
# Out:
# 5 > 10 ? False
# 5 < 10 ? True
# 5 == 10 ? False
# 5 != 10 ? True
# 5 >= 5 ? True
# 5 <= 10 ? True

# %% [markdown]
# #### 5.3. Operadores Lógicos
#
# Usados para combinar expressões booleanas.

# %%
# Definição de variáveis
tem_dinheiro = True
tem_tempo = False

# %%
# Operador AND (e): Ambos precisam ser verdadeiros
print(f'O cliente pode viajar? {tem_dinheiro and tem_tempo}')
# Out:
# O cliente pode viajar? False

# %%
# Operador OR (ou): Pelo menos um precisa ser verdadeiro
print(f"O cliente pode viajar? {tem_dinheiro or tem_tempo}")
# Out:
# O cliente pode viajar? True

# %%
# Operador NOT (não): Inverte o valor booleano
print(f"O cliente pode viajar? {tem_dinheiro and not tem_tempo}")
# Out:
# O cliente pode viajar? True

# %% [markdown]
# #### 6. Manipulação de Strings
#
# Strings são sequências de caracteres e possuem muitos métodos úteis.
#
# .upper() (tudo maiusculo)
#
# .lower() (tudo minúsculo)
#
# .strip() (remove espaço no inicio e no fim)
#
# .title() (primeira letra maiúscula de cada palavra)
#
# .capitalize() (só a primeira letra da string maiúscula)

# %%
# Define uma variável do tipo string
frase = " Aprender Python é divertido! "

# %%
# Concatenação
nome = "Maria"
saudacao = "Olá, " + nome + "!"
print(saudacao)
# Out:
# Olá, Maria!

# %%
# Tamanho da string
print(f"Tamanho da frase: {len(saudacao)} caracteres")
# Out:
# Tamanho da frase: 11 caracteres

# %%
# Maiúsculas e Minúsculas
print(f"Maiúsculas: {frase.upper()}")
print(f"Minusculas: {frase.lower()}")
# Out:
# Maiúsculas:  APRENDER PYTHON É DIVERTIDO!
# Minusculas:  aprender python é divertido!

# %%
# Remover espaços em branco do início e do fim
frase_sem_espaços = frase.strip()
print(f"Frase sem espaços: '{frase_sem_espaços}'")
# Out:
# Frase sem espaços: 'Aprender Python é divertido!'

# %%
# Usando a função upper() e strip() juntas
nome = str(input("Qual é o seu nome? ")).upper().strip()

# %%
print(f"O nome é: {nome}")
# Out:
# O nome é: MARCOS FREIRE DOS SANTOS

# %%
# Usando a função title() e strip() juntas
nome = input("What is your name.: ").title().strip()
print(nome)
# Out:
# Marcos Freire Dos Santos

# %%
# Usando a função title() e strip() juntas
nome = input("Informe o seu nome.: ").strip().capitalize()
sobrenome = input("informe o seu sobrenome.: ").strip().capitalize()
print(f"Seu nome completo é {nome} {sobrenome}")
# Out:
# Seu nome completo é Marcos Freire

# %%
# Substituir texto replace()
texto = "Aprender Python é Divertido"
print(f"Substituindo o texto 'Divertido' por legal.: {texto.replace('Divertido', 'Legal')}")
# Out:
# Substituindo o texto 'Divertido' por legal.: Aprender Python é Legal

# %%
print(f"Frase sem espaços: '{texto}'")
# Out:
# Frase sem espaços: 'Aprender Python é Divertido'

# %%
# Fatiamento (Slicing) - Acessando partes de uma string
# O índice em Python começa em 0

print(texto)
print(f"O primeiro caractere: {texto[0]}")
print(f"A palavra Python: {texto[9:15]}") # Do índice 10 ao 16
# Out:
# Aprender Python é Divertido
# O primeiro caractere: A
# A palavra Python: Python

# %% [markdown]
# **ATENÇÃO MÁXIMA: A INDEXAÇÃO EM PYTHON COMEÇA POR ZERO!**

# %% [markdown]
# #### 7. Estruturas de Dados - Listas
#
# Listas são coleções ordenadas e **mutáveis** de itens. Podem conter diferentes tipos de dados.

# %%
# Criando uma lista
frutas = ["maçã", "banana", "Laranja", "abacaxi"]
print(f"Lista de frutas: {frutas}")
# Out:
# Lista de frutas: ['maçã', 'banana', 'Laranja', 'abacaxi']

# %%
type(frutas)
# Out:
# list

# %%
# Acessando um item pelo índice
print(f"A primeira fruta: {frutas[0]}")
print(f"A ultima fruta: {frutas[-1]}")
# Out:
# A primeira fruta: maçã
# A ultima fruta: abacaxi

# %%
# Adicionando um item ao final da lista
frutas.append("uva")
print(f"Lista de frutas após adicionar 'uva': {frutas}")
# Out:
# Lista de frutas após adicionar 'uva': ['maçã', 'banana', 'Laranja', 'abacaxi', 'uva']

# %%
# Removendo um item da lista
frutas.remove("Laranja")
print(f"Lista de frutas após remover 'laranja': {frutas}")
# Out:
# Lista de frutas após remover 'laranja': ['maçã', 'banana', 'abacaxi', 'uva']

# %%
# Modificando um item da lista
frutas[0] = "morango"
print(f"Lista de frutas após modificar o primeiro item: {frutas}")
# Out:
# Lista de frutas após modificar o primeiro item: ['morango', 'banana', 'abacaxi', 'uva']

# %%
# Podemos imprimir diretamente
print(frutas)
# Out:
# ['morango', 'banana', 'abacaxi', 'uva']

# %%
# Verificando o tamanho da lista
print(f"A lista tem {len(frutas)} frutas")
# Out:
# A lista tem 4 frutas

# %%
# Apagando todos os elementos da lista
frutas.clear()
print(f"Lista vazia {frutas}")
# Out:
# Lista vazia []

# %%
# Deletando a lista
del frutas

# %%
# Lista não pode mais ser acessada
print(frutas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Lista não pode mais ser acessada
# ----> 2 print(frutas)
#
# NameError: name 'frutas' is not defined

# %% [markdown]
# #### 8. Estruturas de Dados - Tuplas
#
# Tuplas são coleções ordenadas e imutáveis de itens. Uma vez criadas, não podem ser alteradas.

# %%
# Criando uma tupla
coordenadas = (10.0, 20,5)
print(f"Tupla de coordenadas: {coordenadas}")
# Out:
# Tupla de coordenadas: (10.0, 20, 5)

# %%
type(coordenadas)
# Out:
# tuple

# %%
# Acessando um item da tupla
print(f"Coordenada X: {coordenadas[0]}")
print(f"Coordenada Y: {coordenadas[1]}")
# Out:
# Coordenada X: 10.0
# Coordenada Y: 20

# %%
# Tentativa de modificar uma tupla resultará em erro
coordenadas[0] = 15.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Tentativa de modificar uma tupla resultará em erro (descomente para ver)
# ----> 2 coordenadas[0] = 15.0
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Tuplas são uteis para dados que não devem ser alterados, como meses do ano, coordenadas, etc
dias_da_semana = ("Segunda", "Terça", "Quarta", "Quinta", "Sexta", "Sábado", "Domingo")
print(f"O primeiro dia da semana é: {dias_da_semana[0]}")
# Out:
# O primeiro dia da semana é: Segunda

# %%
# Convertendo uma tupa em uma lista
tupla_convertida_lista = list(coordenadas)
print(f"Tipo da variável: {type(tupla_convertida_lista)}")
# Out:
# Tipo da variável: <class 'list'>

# %%
tupla_convertida_lista[0] = 25.32
print(f"Novas coordenadas: {tupla_convertida_lista}")
# Out:
# Novas coordenadas: [25.32, 20, 5]

# %%
# Convertendo uma lista para tupla
tupla_coordenadas = tuple(tupla_convertida_lista)
print(f"Tipo de dados: {type(tupla_coordenadas)}")
# Out:
# Tipo de dados: <class 'tuple'>

# %% [markdown]
# #### 9. Estruturas de Dados - Dicionários
#
# Dicionários são coleções de pares chave: valor. São mutáveis.

# %%
# Criando um dicionário de informações de um aluno
aluno = {
    "nome": "Bob",
    "idade": 22,
    "curso": "Data Science Para Análise Multivalorada",
    "aluno_ativo": True
}

# %%
print(f"Dicionário do aluno: {aluno}")
# Out:
# Dicionário do aluno: {'nome': 'Bob', 'idade': 23, 'curso': 'Data Science Para Análise Multivalorada', 'aluno_ativo': True}

# %%
type(aluno)
# Out:
# dict

# %%
# Acessando um valor pela sua chave
print(f"Nome do aluno: {aluno['nome']}") 
print(f"Curso: {aluno.get('curso')}")#.get() é uma forma segura de acessar chaves
# Out:
# Nome do aluno: Bob
# Curso: Data Science Para Análise Multivalorada

# %%
# Adicionando um novo par chave-valor
aluno["cidade"] = "São Paulo"
print(f"Dicionário atualização:\n {aluno}")
# Out:
# Dicionário atualização:
#  {'nome': 'Bob', 'idade': 23, 'curso': 'Data Science Para Análise Multivalorada', 'aluno_ativo': True, 'cidade': 'São Paulo'}

# %%
# Modificando um valor existente
aluno["idade"] = 23
print(f"Idade atualizada: {aluno.get("idade")}")
# Out:
# Idade atualizada: 23

# %%
# Removendo um par valor-chave
del aluno["aluno_ativo"]
print(f"Dicionário após remover a chave 'ativo'.:\n {aluno}")
# Out:
# Dicionário após remover a chave 'ativo'.:
#  {'nome': 'Bob', 'idade': 23, 'curso': 'Data Science Para Análise Multivalorada', 'cidade': 'São Paulo'}

# %% [markdown]
# ##### Dicionário dentro de um dicionário

# %%
estudantes = {
    "aluno1": {"nome": "Ana", "idade": 31, "curso": "Python"},
    "aluno2": {"nome": "Bruno", "idade": 23, "curso": "Java"},
    "aluno3": {"nome": "Carlos", "idade": 22, "curso": "Data Science"}
}

# %%
print(f"Estudantes.: {estudantes}")
# Out:
# Estudantes.: {'aluno1': {'nome': 'Ana', 'idade': 31, 'curso': 'Python'}, 'aluno2': {'nome': 'Bruno', 'idade': 23, 'curso': 'Java'}, 'aluno3': {'nome': 'Carlos', 'idade': 22, 'curso': 'Data Science'}}

# %%
# Acessando os dados
print(f"Estudante 1.: {estudantes.get("aluno1")}")
print(f"Nome do estudante 1.: {estudantes.get("aluno1", "Aluno não encontrado").get("nome")}")
print(f"Curso.: {estudantes.get("aluno1").get("curso")}")
# Out:
# Estudante 1.: {'nome': 'Ana', 'idade': 31, 'curso': 'Python'}
# Nome do estudante 1.: Ana
# Curso.: Python

# %%
# Iterando
for id_aluno, dados in estudantes.items():
    print(f"{id_aluno} -> {dados["nome"]} ({dados["curso"]})")
# Out:
# aluno1 -> Ana (Python)
# aluno2 -> Bruno (Java)
# aluno3 -> Carlos (Data Science)

# %%
# Iterando usando o metodo .get()
for id_aluno, dados in estudantes.items():
    nome = dados.get("nome", "Nome não encontrado")
    curso = dados.get("curso", "Curso não encontrado")
    print(f"{id_aluno} -> {nome} ({curso})")
# Out:
# aluno1 -> Ana (Python)
# aluno2 -> Bruno (Java)
# aluno3 -> Carlos (Data Science)

# %% [markdown]
# ##### Lisa dentro de um Dicionário

# %%
turma = {
    "nomes": ["Ana", "Bruno", "Carlos"],
    "idade": [21, 23, 22],
    "cursos": ["Python", "Java", "Data Science"]
}

# %%
print(f"Nome dos alunos(a).: {turma["nomes"]}")
print(f"Aluna.: {turma["nomes"][0]}")
print(f"Cursando.: {turma["cursos"][2]}")
# Out:
# Nome dos alunos(a).: ['Ana', 'Bruno', 'Carlos']
# Aluna.: Ana
# Cursando.: Data Science

# %%
# Iterando
for i in range(len(turma["nomes"])):
    print(f"{turma["nomes"][i]} ({turma["cursos"][i]}) - {turma["idade"][i]} anos")
# Out:
# Ana (Python) - 21 anos
# Bruno (Java) - 23 anos
# Carlos (Data Science) - 22 anos

# %% [markdown]
# ##### Tupla dentro do dicionário

# %%
locais = {
    "SP": ("São Paulo", 12_000_000),
    "RJ": ("Rio de Janeiro", 6_700_000),
    "MG": ("Belo Horizonte", 2_500_000)
}

# %%
print(locais["SP"])
print(locais["SP"][0])
print(locais["SP"][1])
# Out:
# ('São Paulo', 12000000)
# São Paulo
# 12000000

# %%
for sigla, (cidade, populacao) in locais.items():
    print(f"{sigla} -> {cidade} tem {populacao:,} habitantes")
# Out:
# SP -> São Paulo tem 12,000,000 habitantes
# RJ -> Rio de Janeiro tem 6,700,000 habitantes
# MG -> Belo Horizonte tem 2,500,000 habitantes

# %% [markdown]
# ##### Dicionários + Listas + Dicionários (estrutura mais comum em APIS)

# %%
empresa = {
    "nome": "TechData",
    "departamentos": [
        {"nome": "TI", "funcionarios": ["Ana", "Bruno", "Carlos"]},
        {"nome": "RH", "funcionarios": ["Daniela", "Eduardo"]},
        {"nome": "Financeiro", "funcionarios": ["Fernanda"]}
    ]
}

# %%
print(empresa["departamentos"][0]["funcionarios"])
print(empresa["departamentos"][1]["nome"])
print(empresa["departamentos"][2]["funcionarios"][0])
# Out:
# ['Ana', 'Bruno', 'Carlos']
# RH
# Fernanda

# %%
# Iterando
for depto in empresa["departamentos"]:
    print(f"Departamento: {depto["nome"]}")
    for funcionario in depto["funcionarios"]:
        print(f" - {funcionario}")
# Out:
# Departamento: TI
#  - Ana
#  - Bruno
#  - Carlos
# Departamento: RH
#  - Daniela
#  - Eduardo
# Departamento: Financeiro
#  - Fernanda

# %% [markdown]
# ##### 10. Estruturas de Dados - Conjuntos (Sets)
#
# Conjuntos são coleções não ordenadas de itens únicos e mutáveis. Eles são úteis para remover duplicatas e realizar operações matemáticas de conjuntos (união, interseção).

# %%
# Criando um conjunto (note que os itens duplicados são removidos)
numeros = {1, 2, 3, 4, 2, 3, 5}
print(f"Conjunto de números (sem duplicatas).: {numeros}")
# Out:
# Conjunto de números (sem duplicatas).: {1, 2, 3, 4, 5}

# %%
type(numeros)
# Out:
# set

# %%
# Adicionando um item
numeros.add(6)
print(f"Após adicionar o valor 6.: {numeros}")
# Out:
# Após adicionar o valor 6.: {1, 2, 3, 4, 5, 6}

# %%
# Removendo um item
numeros.remove(2)
print(f"Após remover o 2.: {numeros}")
# Out:
# Após remover o 2.: {1, 3, 4, 5, 6}

# %%
# Operações de conjunto
conjunto_a = {1, 2, 3, 4}
conjunto_b = {3, 4, 5, 6}

# %%
# União (todos os elementos de ambos os conjuntos)
uniao = conjunto_a.union(conjunto_b)
print(f"União de A e B: {uniao}")
# Out:
# União de A e B: {1, 2, 3, 4, 5, 6}

# %%
# Interseção (elementos que estão em ambos os conjuntos)
intersecao = conjunto_a.intersection(conjunto_b)
print(f"Interseção de A e B.: {intersecao}")
# Out:
# Interseção de A e B.: {3, 4}

# %% [markdown]
# ##### 11. Conversão Entre Tipos de Dados (Type Casting)
#
# É a conversão de um tipo de dado para outro.

# %%
# Convertendo de string para número integer
numero_em_texto = "123" 
numero_inteiro = int(numero_em_texto)
print(f"String '{numero_em_texto}' para Inteiro.: {numero_inteiro}, Tipo.: {type(numero_inteiro)}")
# Out:
# String '123' para Inteiro.: 123, Tipo.: <class 'int'>

# %%
# Isso aqui não pode ser feito
teste = "Esta é uma string de teste"
teste_int = int(teste)
print(teste_int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Isso aqui não pode ser feito
#       2 teste = "Esta é uma string de teste"
# ----> 3 teste_int = int(teste)
#       4 print(teste_int)
#
# ValueError: invalid literal for int() with base 10: 'Esta é uma string de teste'

# %%
# Convertendo de string para número float
numero_decimal_em_texto = "45.67"
numero_float = float(numero_decimal_em_texto)
print(f"String '{numero_decimal_em_texto}' para float.: {numero_float}, Tipo.: {type(numero_float)}")
# Out:
# String '45.67' para float.: 45.67, Tipo.: <class 'float'>

# %%
# Convertendo de Integer para float
numero_inteiro_para_decimal = 25
numero_decimal = float(numero_inteiro_para_decimal)
print(f"Integer '{numero_inteiro_para_decimal}' para float.: {numero_decimal} Tipo.: {type(numero_decimal)}")
# Out:
# Integer '25' para float.: 25.0 Tipo.: <class 'float'>

# %%
# Convertendo de float para integer
numero_decimal_para_inteiro = 25.0
numero_inteiro = int(numero_decimal_para_inteiro)
print(f"Integer '{numero_decimal_para_inteiro}' para float.: {numero_inteiro} Tipo.: {type(numero_inteiro)}")
# Out:
# Integer '25.0' para float.: 25 Tipo.: <class 'int'>

# %%
# Convertendo de número para string
idade = 25
idade_em_texto = str(idade)
print(f"Integer {idade} para String.: {idade_em_texto} Tipo.: {type(idade_em_texto)}")
# Out:
# Integer 25 para String.: 25 Tipo.: <class 'str'>

# %%
# Convertendo entre estruturas de dados
lista_com_duplicatas = [1, 2, 2, 3, 4, 4, 4, 5]
conjunto_unico = set(lista_com_duplicatas)
lista_sem_duplicatas = list(conjunto_unico)

# %%
print(f"\nLista original.: {lista_com_duplicatas}")
print(f"\nConvertida para Conjunto (remove duplicatas).: {conjunto_unico}")
print(f"\nConvertida de volta para lista.: {lista_sem_duplicatas}")
# Out:
# Lista original.: [1, 2, 2, 3, 4, 4, 4, 5]
#
# Convertida para Conjunto (remove duplicatas).: {1, 2, 3, 4, 5}
#
# Convertida de volta para lista.: [1, 2, 3, 4, 5]

# %% [markdown]
# #### 12. Entrada e Saída Padrão
#
# A forma mais comum de interagir com o usuário é através da entrada (input) de dados pelo teclado e da saída (output) de informações na tela.
#
# ##### 12.1. Saída de Dados com print()
#
# Já usamos bastante, mas aqui estão alguns recursos adicionais, como as f-strings.

# %%
# Variáveis
nome = "Juliana"
idade = 28
cidade = "Rio de Janeiro"

# Usando f-string (a forma mais moderna e recomendada)
print(f"Olá meu nome é {nome}, tenho {idade} anos e moro no {cidade}")
print() # para dar um espaço entre os prints
# Formatação de números
preco = 49.95678
print(f"O preço do produto é R$ {preco:.2f}") # Formata para duas casas decimais
# Out:
# Olá meu nome é Juliana, tenho 28 anos e moro no Rio de Janeiro
#
# O preço do produto é R$ 49.96

# %% [markdown]
# #### 12.2. Entrada de Dados com input()
#
# A função input() sempre retorna uma string. Por isso, é comum precisar fazer o type casting.

# %%
# Pedindo o nome do usuário (string)
nome_usuario = str(input("Qual é o seu nome.:")).strip().capitalize()

# Pedindo a idade do usuário (preciva converter para int)
idade_usuario = int(input("Informe a sua idade.:"))

from datetime import date

# Pega o ano corrente na data definida no sistema operacional da sua máquina
ano_atual = date.today().year 

# Processando dados
ano_nascimento = ano_atual - idade_usuario

# Exibindo o resultado
print(f"\nOlá, {nome_usuario}! Bem-vindo(a)")
print(f"Você tem {idade_usuario} anos e nasceu aproximadamente em {ano_nascimento}")
# Out:
# Olá, Marcos! Bem-vindo(a)
# Você tem 45 anos e nasceu aproximadamente em 1980

# %% [markdown]
# ### EXERCÍCIOS

# %% [markdown]
# #### Exercício 1
#
# Escreva um programa que peça ao usuário para digitar seu nome e, em seguida, imprima uma mensagem de boas-vindas com o nome fornecido.

# %%
nome = str(input("Digite o seu nome.: ")).strip().title()
print(f"Seja bem a Data Science Academy, {nome}!")
# Out:
# Seja bem a Data Science Academy, Marcos Freire Dos Santos

# %% [markdown]
# #### Exercício 2
#
# Crie duas variáveis, numero1 e numero2, e atribua a elas valores inteiros. Calcule a soma, subtração, multiplicação e divisão dessas variáveis e imprima os resultados.

# %%
numero1 = 10
numero2 = 2

print(f"{numero1} + {numero2} = {numero1 + numero2}")
print(f"{numero1} - {numero2} = {numero1 - numero2}")
print(f"{numero1} * {numero2} = {numero1 * numero2}")
print(f"{numero1} / {numero2} = {numero1 / numero2}")
# Out:
# 10 + 2 = 12
# 10 - 2 = 8
# 10 * 2 = 20
# 10 / 2 = 5.0

# %% [markdown]
# #### Exercício 3
#
# Qual é a principal diferença entre uma variável de escopo local e uma de escopo global?

# %%
# Variável de escopo é usada só dentro do escopo 
# Já a variavel global é usada dentro e fora do escopo

# %% [markdown]
# #### Exercício 4
#
# Crie uma variável chamada saldo com o valor 500.50 (float). Em seguida, crie uma variável saque com o valor 200.25 (float). Subtraia o saque do saldo e imprima o saldo final formatado para duas casas decimais.

# %%
saldo = 500.50
saque = 200.25
saldo_final = saldo - saque
print(f"Saldo final.: R$ {saldo_final}")
# Out:
# Saldo final.: 300.25

# %% [markdown]
# #### Exercício 5
#
# Declare uma variável booleana chamada **tem_carteira_de_motorista** e atribua a ela o valor True. Imprima uma mensagem que diga "Pode dirigir" se a variável for verdadeira e "Não pode dirigir" caso contrário.

# %%
tem_carteira_de_motorista = True

if tem_carteira_de_motorista:
    print("Sim, ele tem carteira de motorista")
else:
    print("Não, ele não tem carteira de motorista")
# Out:
# Sim, ele tem carteira de motorista

# %% [markdown]
# #### Exercício 6
#
# Crie duas variáveis:
#
# - idade_ana = 25
# - idade_beto = 30
#
# Use operadores de comparação para verificar se a idade de Ana é menor que a de Beto e imprima o resultado booleano.

# %%
idade_ana = 25
idade_beto = 30

if idade_ana < idade_beto:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# #### Exercício 7
#
# Receba um número inteiro do usuário e use o operador de módulo (%) para verificar se o número é par ou ímpar. Imprima o resultado.
#
# Obs: Não estudamos ainda os condicionais, mas pesquise se necessário e tente resolver.

# %%
numero = int(input("Informe um número.: "))

if numero % 2 == 0:
    print(f"O número {numero} é par!")
else:
    print(f"O número é impar!")
# Out:
# O número é impar!

# %% [markdown]
# #### Exercício 8
#
# Crie duas variáveis booleanas:
#
# - chovendo = True
# - guarda_chuva = False
#
# Use operadores lógicos para verificar se uma pessoa vai se molhar (se está chovendo E ela não tem guarda-chuva).

# %%
chovendo = True
guarda_chuva = False

vai_se_molhar = chovendo and not guarda_chuva
print(F"A pessoa vai se melhar.: {vai_se_molhar}")
# Out:
# A pessoa vai se melhar.: True

# %% [markdown]
# #### Exercício 9
#
# Calcule a potência de 2 elevado a 10 e imprima o resultado.

# %%
potencia = 2 ** 10
print(f"2 elvado a 10 .: {potencia}")
# Out:
# 2 elvado a 10 .: 1024

# %% [markdown]
# #### Exercício 10
#
# Converta a string "2026" para um tipo inteiro e armazene-a em uma variável chamada ano. Em seguida, some 1 a essa variável e imprima o novo ano.

# %%
variavel_string = '2026'
ano = int(variavel_string)
print(f" Novo ano de {ano + 1}")
# Out:
#  Novo ano de 2027

# %% [markdown]
# #### Exercício 11
#
# Crie a string:
#
# frase = "   Python é uma linguagem poderosa e estou aprendendo com a DSA   ".
#
# Remova os espaços em branco do início e do fim da string e imprima a nova string.

# %%
frase = "   Python é uma linguagem poderosa e estou aprendendo com a DSA   "
print(f"{frase.strip()}")
# Out:
# Python é uma linguagem poderosa e estou aprendendo com a DSA

# %% [markdown]
# #### Exercício 12
#
# Na string do exercício anterior (já sem os espaços), converta toda a frase para letras maiúsculas.

# %%
print(f"Frase convertidad para maiusculas.: {frase.upper()}")
# Out:
# Frase convertidad para maiusculas.:    PYTHON É UMA LINGUAGEM PODEROSA E ESTOU APRENDENDO COM A DSA

# %% [markdown]
# #### Exercício 13
#
# Ainda usando a mesma string, substitua a palavra "poderosa" por "incrível".

# %%
frase_modificada = frase.replace('poderosa', 'incrível')
print(f"Substituindo a palavra  'poderosa' por 'incrível'.: {frase_modificada.strip()}")
# Out:
# Substituindo a palavra  'poderosa' por 'incrível'.: Python é uma linguagem incrível e estou aprendendo com a DSA

# %% [markdown]
# #### Exercício 14
#
# Verifique e imprima o número total de caracteres na string frase (após as modificações dos exercícios anteriores).

# %%
quantidade_de_caracteres = len(frase.strip())
print(f"O quantidade de caracteres da frase {frase_modificada.strip()} é.: {quantidade_de_caracteres}")
# Out:
# O quantidade de caracteres da frase Python é uma linguagem incrível e estou aprendendo com a DSA é.: 60

# %% [markdown]
# #### Exercício 15
#
# Use fatiamento (slicing) para extrair e imprimir apenas a palavra "Python" da string frase.

# %%
print(f"{frase.strip()[0:6]}")
# Out:
# Python

# %% [markdown]
# #### Exercício 16
#
# Crie uma lista chamada compras com os seguintes itens: "arroz", "feijão", "macarrão", "carne". Imprima a lista.

# %%
# Primeira versão do exercício
compras = ["arroz", "feijão", "macarrao", "carne"]
print(f"Minhas compras.: {compras}")
# Out:
# Minhas compras.: ['arroz', 'feijão', 'macarrao', 'carne']

# %%
# Segunda versão usando .join()
compras = ["arroz", "feijão", "macarrao", "carne"]
print(f"Minhas compras.: {', '.join(compras)}")
# Out:
# Minhas compras.: arroz, feijão, macarrao, carne

# %%
# Terceira versão unsando .join()
compras = ["arroz", "feijão", "macarrao", "carne"]
print(f"Minhas compras.: {', '.join(compras[:-1])} e {compras[-1]}")
# Out:
# Minhas compras.: arroz, feijão, macarrao e carne

# %% [markdown]
# #### Exercício 17
#
# Adicione o item "leite" ao final da lista compras e imprima a lista atualizada.

# %%
compras.append("leite")
print(f"Lista atualizada {', '.join(compras)}")
# Out:
# Lista atualizada arroz, feijão, macarrao, carne, leite

# %% [markdown]
# #### Exercício 18
#
# Acesse e imprima o segundo item da lista compras.

# %%
print(f"Item da compra na segunda posição da lista.: {compras[2]}")
# Out:
# Item da compra na segunda posição da lista.: macarrao

# %% [markdown]
# #### Exercício 19
#
# Remova o item "macarrão" da lista compras e imprima a lista final.

# %%
compras.remove("macarrao")
print(f"Lista de compras após remover o item 'macarrão' {compras}")
# Out:
# Lista de compras após remover o item 'macarrão' ['arroz', 'feijão', 'carne', 'leite']

# %% [markdown]
# #### Exercício 20
#
# Crie uma lista de números de 1 a 5. Use uma função para calcular e imprimir o tamanho (número de elementos) dessa lista.

# %%
numeros = [1, 2, 3, 4, 5]
print(f"O tamanho da lista números.: {len(numeros)}")
# Out:
# O tamanho da lista números.: 5

# %% [markdown]
# #### Exercício 21
#
# Crie uma tupla chamada meses com os três primeiros meses do ano: "Janeiro", "Fevereiro", "Março".

# %%
meses = ("Janeiro", "Fevereiro", "Março")

# %% [markdown]
# #### Exercício 22
#
# Tente adicionar o mês "Abril" à tupla meses. O que acontece? Explique o resultado.

# %%
# Não é possível inserir um dado diretamente em uma tupla, pois ela é imutavel.

# %% [markdown]
# #### Exercício 23
#
# Acesse e imprima o primeiro mês da tupla meses.

# %%
print(f"O primeiro mês da tupla: {meses[0]}")
# Out:
# O primeiro mês da tupla: Janeiro

# %% [markdown]
# #### Exercício 24
#
# Crie um dicionário chamado filme com as seguintes chaves e valores:
#
# - titulo = "O Poderoso Chefão",
# - ano = 1972
# - diretor = "Francis Ford Coppola"

# %%
filme = {
    "titulo": "O Pederoso Chefão",
    "ano": 1972,
    "diretor": "Francis Ford Coppola"
    }

# %% [markdown]
# #### Exercício 25
#
# Acesse e imprima o ano de lançamento do filme a partir do dicionário.

# %%
print(f"Ano de lançamento: {filme["ano"]}")
# Out:
# Ano de lançamento: 1972

# %% [markdown]
# #### Exercício 26
#
# Adicione uma nova chave genero com o valor "Drama" ao dicionário filme e imprima o dicionário completo.

# %%
filme["genero"] = "Drama"
print(f"Dicionário com inclusão do genero: {filme}")
# Out:
# Dicionário com inclusão do genero: {'titulo': 'O Pederoso Chefão', 'ano': 1972, 'diretor': 'Francis Ford Coppola', 'genero': 'Drama'}

# %% [markdown]
# #### Exercício 27
#
# Modifique o valor da chave ano para 1973 e imprima o dicionário atualizado.

# %%
filme["ano"] = 1973
print(f"Dicionário filme atualizado: {filme}")
# Out:
# Dicionário filme atualizado: {'titulo': 'O Pederoso Chefão', 'ano': 1973, 'diretor': 'Francis Ford Coppola', 'genero': 'Drama'}

# %% [markdown]
# #### Exercício 28
#
# Crie uma lista com os seguintes números: [1, 2, 2, 3, 4, 4, 5, 1]. Use um conjunto para remover os números duplicados e imprima o resultado.

# %%
numeros = [1, 2, 2, 3, 4, 4, 5, 1]
numero_sem_duplicacao = set(numeros)
print(f"Números em duplicação: {numero_sem_duplicacao}")
# Out:
# Números em duplicação: {1, 2, 3, 4, 5}

# %% [markdown]
# #### Exercício 29
#
# Crie dois conjuntos:
#
# - set_a = {1, 2, 3, 4}
# - set_b = {3, 4, 5, 6}
#
# Encontre e imprima a interseção entre os dois conjuntos (os elementos que estão em ambos).

# %%
set_a = {1, 2, 3, 4}
set_b = {3, 4, 5, 6}
intersecao = set_a.intersection(set_b)
print(intersecao)
# Out:
# {3, 4}

# %% [markdown]
# #### Exercício 30
#
# Escreva um programa que peça ao usuário para digitar sua altura em metros (ex: 1.75) e seu peso em quilogramas (ex: 68.5). Calcule o Índice de Massa Corporal (IMC) usando a fórmula IMC = peso / (altura * altura) e imprima o resultado formatado com duas casas decimais.

# %%
altura = float(input("Informe a sua altura: "))
peso = float(input("Informe seu peso em quilogramas: "))

imc = peso / (altura * altura)

print(f"Seu IMC é de: {imc:.2f}")
# Out:
# Seu IMC é de: 22.37
